# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv("/content/drive/MyDrive/Dataset/Mall_Customers.csv")
df.head()
# Out:
#    CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
plt.figure(figsize=(10,7))
sns.heatmap(df.corr(), annot=True)
plt.title('Correlation between the columns')
plt.show()
# Out:
# <ipython-input-4-2b93e5a31d83>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), annot=True)

# %%
plt.figure(figsize=(10,7))
sns.heatmap(df.corr(method="spearman"), annot=True)
plt.title('Correlation between the columns')
plt.show()
# Out:
# <ipython-input-5-b8eb60789546>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(method="spearman"), annot=True)

# %%
plt.figure(figsize=(10,7))
sns.heatmap(df.corr(method="pearson"), annot=True)
plt.title('Correlation between the columns')
plt.show()
# Out:
# <ipython-input-7-8730ae53a53e>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(method="pearson"), annot=True)

# %%
plt.figure(figsize=(10,7))
sns.heatmap(df.corr(method="kendall"), annot=True)
plt.title('Correlation between the columns')
plt.show()
# Out:
# <ipython-input-8-5a3ca6d8599a>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(method="kendall"), annot=True)
